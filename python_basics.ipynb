# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabh6268/Python-Assignments/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Write a Python program to print Hello, World!.

print("Hello, World!")
# Out:
# Hello, World!

# %%
 #2 Write a program to print your name using the print() function.

 name="Saurabh Dhakad"
 print("My name is",name)
# Out:
# My name is Saurabh Dhakad

# %%
'''Write a Python program that prints your name and age using two separate print()
statements.'''

print("My name is Saurabh Dhakad")
print("I am 21 years old")
# Out:
# My name is Saurabh Dhakad
# I am 21 years old

# %%
#4 Take your name as input from the user and print:

name=input("Enter Name:")
print(f"My name is {name}")
# Out:
# Enter Name:Saurabh
# My name is Saurabh

# %%
 #5 Take name and age from the user and print:

name=input("Enter Name:")
age=int(input("Enter your age:"))
print(f"Your name is {name} and you are {age} yeras old")
# Out:
# Enter Name:Saurabh Dhakad
# Enter your age:21
# Your name is Saurabh Dhakad and you are 21 yeras old

# %%
#6 Store your name and favorite color in variables and print a sentence like:

name="Saurabh Dhakad"
fvt_color="Blue"
print(f"Hi, I'm {name} and my favorite color is {fvt_color}")
# Out:
# Hi, I'm Saurabh Dhakad and my favorite color is Blue

# %%
#7 Write a Python program to take two numbers from the user, add them, and print the result.

num_1=int(input("Enter Num1:"))
num_2=int(input("Enter Num2:"))
print("Sum of 2 Numbers is:",num_1+num_2)
# Out:
# Enter Num1:458
# Enter Num2:215
# Sum of 2 Numbers is: 673

# %%
#8 Take age input from user as string and convert it to integer.

age=input("Enter your age:")
new_age=int(age)
print(f"You will be {new_age+1} next year")
# Out:
# Enter your age:21
# You will be 22 next year

# %%
#9 Take a word as input from the user and print the number of characters in it.

a=input("Enter a word:")
print(len(a))
# Out:
# Enter a word:Python
# 6

# %%
#10 Take the user's name and greet them like:
# Hello <name>, welcome to Python Programming!

user_name=input("Enter User's Name:")
print(f"Hello {user_name}, welcome to Python programming!")
# Out:
# Enter User's Name:Saurabh Dhakad
# Hello Saurabh Dhakad, welcome to Python programming!
