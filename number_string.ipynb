# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabh6268/Python-Assignments/blob/main/number_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Write a Python program to add two integers.

a=5
b=3
print("Sum of a and b is:", a+b)
# Out:
# Sum of a and b is: 8

# %%
#2 Write a program to multiply two float numbers.

x=2.5
y=1.5
print("Product of x and y is:", x*y)
# Out:
# Product of x and y is: 3.75

# %%
#3 Create a Python function to add two complex numbers.

z1=2+3j
z2=1-1j
print("Sum of z1 and z2 is:", z1+z2)
# Out:
# Sum of z1 and z2 is: (3+2j)

# %%
#4 Write a program to perform integer divison of two numbers.

a=7
b=2
print("Divison of a by b is:", int(a/2))
# Out:
# Divison of a by b is: 3

# %%
#5 Create a function to calculate the power of a number.

a_base=2
b_exponent=3
print("a to the power b will become:", a_base**b_exponent)
# Out:
# a to the power b will become: 8

# %%
#6 Write a program to display a float number with 2 decimal places.

num=3.14159
print("Number upto 2 decimal places will be:",format(num,".2f"))
# Out:
# Number upto 2 decimal places will be: 3.14

# %%
#7 Write a Python function to find the conjugate of a given complex number.

z=4-3j
print("Conjugate of z is:",z.conjugate())
# Out:
# Conjugate of z is: (4+3j)

# %%
#8 Create a program to find the absolute value of an integer.

a=-5
print("Absolute value of a is:",abs(a))
# Out:
# Absolute value of a is: 5

# %%
#9 Program to compare two float numbers with a tolerance.

x = 1.234
y = 1.235
tolr = 0.0011

if abs(x - y) <= tolr:
    print("Approximately equal.")
else:
    print("Not equal.")
# Out:
# Approximately equal.

# %%
#10 Write a function to extract the real part of a complex number.

z=2+4j
print("Real part of z is:",int(z.real))
# Out:
# Real part of z is: 2

# %%
#11 Write a program to concatenate two strings.

str_1="Hello"
str_2="World"
print("Strings after concatenation:",str_1 +" "+str_2)
# Out:
# Strings after concatenation: Hello World

# %%
#12 Create a program to find the length of a string.

str_len="Python is fun"
print("Length of string is:",len(str_len))
# Out:
# Length of string is: 13

# %%
#13 Write a program to slice a string to get a substring.

str_slc="Python Programming"
print("String after slicing:",str_slc[2:8])
# Out:
# String after slicing: thon P

# %%
#14 Write a program to convert a string to uppercase.

str_lcase="hello"
print("Upper Case:",str_lcase.upper())
# Out:
# Upper Case: HELLO

# %%
#15 Create a program to convert a string to lowercase.

str_ucase="WORLD"
print("Lower Case:",str_ucase.lower())
# Out:
# Lower Case: world

# %%
#16 Write a program to capitalize the first letter of a string.

str_1="python programming"
print("String after capitalize:",str_1.capitalize())
# Out:
# String after capitalize: Python programming

# %%
#17 Create a function to reverse a string.

str_1="abcde"
print("Reversed String:",str_1[::-1])
# Out:
# Reversed String: edcba

# %%
#18 Write a program to count the occurrences of a substring in a string.

str_1="hello hello world"
sub_str="hello"
print("Occurrence of hello:",str_1.count(sub_str))
# Out:
# Occurrence of hello: 2

# %%
#19 Create a program to replace a substring within a string.

str_1="Hello World"
print("After Replace New String:",str_1.replace("World","Universe"))
# Out:
# After Replace New String: Hello Universe

# %%
#20 Write a program to split a string into a list of words.

str_1="Python is easy"
print("String after splitting:",str_1.split())
# Out:
# String after splitting: ['Python', 'is', 'easy']
